# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('D:/PROJECT/mushrooms.csv')
df
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %% [markdown]
# # EDA

# %%
df.info() # Basic Information of the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   object
#  1   cap-shape                 8124 non-null   object
#  2   cap-surface               8124 non-null   object
#  3   cap-color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill-attachment           8124 non-null   object
#  7   gill-spacing              8124 non-null   object
#  8   gill-size                 8124 non-null   object
#  9   gill-color                8124 non-null   object
#  10  stalk-shape               8124 non-null   object
#  11  stalk-root                8124 non-null   object
#  12  stalk-surface-above-ring  8124 non-null   object
# ...

# %%
df.describe() # To describe the data
# Out:
#        class cap-shape cap-surface cap-color bruises  odor gill-attachment  \
# count   8124      8124        8124      8124    8124  8124            8124
# unique     2         6           4        10       2     9               2
# top        e         x           y         n       f     n               f
# freq    4208      3656        3244      2284    4748  3528            7914
#
#        gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# count          8124      8124       8124  ...                     8124
# unique            2         2         12  ...                        4
# top               c         b          b  ...                        s
# freq           6812      5612       1728  ...                     4936
#
#        stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# count                    8124                   8124      8124       8124
# unique                      9                      9         1          4
# ...

# %%
df.duplicated().sum() # To find duplicate values
# Out:
# 0

# %%
df.head() # To view the data
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %%
df['class'].unique() # list down any missing values (nan) as well
# Out:
# array(['p', 'e'], dtype=object)

# %%
len(df['class'].unique()) # counted nan values also
# Out:
# 2

# %%
df['class'].nunique() # Count of distinct categories in our variable but this time we don't want to count any nan values
# Out:
# 2

# %%
nrow, ncol = df.shape
nrow, ncol
(df['class'].isnull().sum()/ nrow).round(3)*100 # Percentage of missing values and keep only 1 decimal place
# Out:
# 0.0

# %%
# Frequency distribution
# (a) Count Plot
import seaborn as sns
sns.countplot(data = df, x = 'class')
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %% [markdown]
# # Cap-Shapes

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15, 8))
splot = sns.countplot(data=df, x='cap-shape', hue='class', order=df['cap-shape'].value_counts().index, palette=['red', 'forestgreen'], edgecolor=(0, 0, 0),linewidth=2)
                      
splot.set_xticklabels(['Convex', 'Flat', 'Knobbed', 'Bell', 'Sunken', 'Conical'])

for p in splot.patches:
    splot.annotate(format(p.get_height(), '.1f'),
                   (p.get_x() + p.get_width() / 2., p.get_height()),
                   ha='center', va='center',
                   xytext=(0, 9),
                   textcoords='offset points')
                   
plt.legend(['Poisonous', 'Edible'], loc='upper right')
plt.ylabel('Number of the Mushrooms', fontsize=14)
plt.xlabel('Types of the Cap Shapes of the Mushrooms', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title('Distribution of the Mushrooms by their Classes and Cap Shapes', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Distribution of the Mushrooms by their Classes and Cap Shapes')

# %% [markdown]
# # Cap-Surface

# %%
plt.figure(figsize=(15, 8))
splot = sns.countplot(data=df, x='cap-surface', hue='class', order=df['cap-surface'].value_counts().index, palette=['red', 'forestgreen'], edgecolor=(0, 0, 0),linewidth=2)
                      
splot.set_xticklabels(['Fibrous', 'Grooves', 'Scaly', 'Smooth'])

for p in splot.patches:
    splot.annotate(format(p.get_height(), '.1f'),
                   (p.get_x() + p.get_width() / 2., p.get_height()),
                   ha='center', va='center',
                   xytext=(0, 9),
                   textcoords='offset points')
                   
plt.legend(['Poisonous', 'Edible'], loc='upper right')
plt.ylabel('Number of the Mushrooms', fontsize=14)
plt.xlabel('Types of the Cap Surfacess of the Mushrooms', fontsize=14)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.title('Distribution of the Mushrooms by their Classes and Cap Surfaces', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Distribution of the Mushrooms by their Classes and Cap Surfaces')

# %% [markdown]
# # Cap-Color

# %%
plt.figure(figsize=(15, 8))
splot = sns.countplot(data=df, x='cap-color', hue='class', order=df['cap-color'].value_counts().index, palette=['red', 'forestgreen'], edgecolor=(0, 0, 0),linewidth=2)
                      
splot.set_xticklabels(['Brown', 'Buff', 'Cinnamon', 'Gray', 'Green', 'Pink', 'Purple', 'Red', 'White', 'Yellow'])

for p in splot.patches:
    splot.annotate(format(p.get_height(), '.1f'),
                   (p.get_x() + p.get_width() / 2., p.get_height()),
                   ha='center', va='center',
                   xytext=(0, 9),
                   textcoords='offset points')
                   
plt.legend(['Poisonous', 'Edible'], loc='upper right')
plt.ylabel('Number of the Mushrooms', fontsize=14)
plt.xlabel('Types of the Cap Colors of the Mushrooms', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title('Distribution of the Mushrooms by their Classes and Cap Colors', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Distribution of the Mushrooms by their Classes and Cap Colors')

# %% [markdown]
# # Bruises

# %%
plt.figure(figsize=(15, 8))
splot = sns.countplot(data=df, x='bruises', hue='class', order=df['bruises'].value_counts().index, palette=['red', 'forestgreen'], edgecolor=(0, 0, 0),linewidth=2)
                      
splot.set_xticklabels(['Bruises', 'No'])

for p in splot.patches:
    splot.annotate(format(p.get_height(), '.1f'),
                   (p.get_x() + p.get_width() / 2., p.get_height()),
                   ha='center', va='center',
                   xytext=(0, 9),
                   textcoords='offset points')
                   
plt.legend(['Poisonous', 'Edible'], loc='upper right')
plt.ylabel('Number of the Mushrooms', fontsize=14)
plt.xlabel('Types of the Bruises of the Mushrooms', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title('Distribution of the Mushrooms by their Classes and Cap Bruises', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Distribution of the Mushrooms by their Classes and Cap Bruises')

# %% [markdown]
# # Odor

# %%
plt.figure(figsize=(15, 8))
splot = sns.countplot(data=df, x='odor', hue='class', order=df['odor'].value_counts().index, palette=['red', 'forestgreen'], edgecolor=(0, 0, 0),linewidth=2)
                      
splot.set_xticklabels(['Almond', 'Anise', 'Creosote', 'Fishy', 'Foul', 'Musty', 'None', 'Pungent', 'Spicy'])

for p in splot.patches:
    splot.annotate(format(p.get_height(), '.1f'),
                   (p.get_x() + p.get_width() / 2., p.get_height()),
                   ha='center', va='center',
                   xytext=(0, 9),
                   textcoords='offset points')
                   
plt.legend(['Poisonous', 'Edible'], loc='upper right')
plt.ylabel('Number of the Mushrooms', fontsize=14)
plt.xlabel('Types of the Odor of the Mushrooms', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title('Distribution of the Mushrooms by their Classes and Odor', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Distribution of the Mushrooms by their Classes and Odor')

# %% [markdown]
# # Gill-Attachment

# %%
plt.figure(figsize=(15, 8))
splot = sns.countplot(data=df, x='gill-attachment', hue='class', order=df['gill-attachment'].value_counts().index, palette=['red', 'forestgreen'], edgecolor=(0, 0, 0),linewidth=2)
                      
splot.set_xticklabels(['Attached', 'Free'])

for p in splot.patches:
    splot.annotate(format(p.get_height(), '.1f'),
                   (p.get_x() + p.get_width() / 2., p.get_height()),
                   ha='center', va='center',
                   xytext=(0, 9),
                   textcoords='offset points')
                   
plt.legend(['Poisonous', 'Edible'], loc='upper right')
plt.ylabel('Number of the Mushrooms', fontsize=14)
plt.xlabel('Types of the gill-attachment of the Mushrooms', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title('Distribution of the Mushrooms by their Classes and Gill-Attachment', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Distribution of the Mushrooms by their Classes and Gill-Attachment')

# %% [markdown]
# # Gill-Spacing

# %%
plt.figure(figsize=(15, 8))
splot = sns.countplot(data=df, x='gill-spacing', hue='class', order=df['gill-spacing'].value_counts().index, palette=['red', 'forestgreen'], edgecolor=(0, 0, 0),linewidth=2)
                      
splot.set_xticklabels(['Close', 'Crowded'])

for p in splot.patches:
    splot.annotate(format(p.get_height(), '.1f'),
                   (p.get_x() + p.get_width() / 2., p.get_height()),
                   ha='center', va='center',
                   xytext=(0, 9),
                   textcoords='offset points')
                   
plt.legend(['Poisonous', 'Edible'], loc='upper right')
plt.ylabel('Number of the Mushrooms', fontsize=14)
plt.xlabel('Types of the gill-spacing of the Mushrooms', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title('Distribution of the Mushrooms by their Classes and Gill-Spacing', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Distribution of the Mushrooms by their Classes and Gill-Spacing')

# %% [markdown]
# # Gill-Size

# %%
plt.figure(figsize=(15, 8))
splot = sns.countplot(data=df, x='gill-size', hue='class', order=df['gill-size'].value_counts().index, palette=['red', 'forestgreen'], edgecolor=(0, 0, 0),linewidth=2)
                      
splot.set_xticklabels(['Broad', 'Narrow'])

for p in splot.patches:
    splot.annotate(format(p.get_height(), '.1f'),
                   (p.get_x() + p.get_width() / 2., p.get_height()),
                   ha='center', va='center',
                   xytext=(0, 9),
                   textcoords='offset points')
                   
plt.legend(['Poisonous', 'Edible'], loc='upper right')
plt.ylabel('Number of the Mushrooms', fontsize=14)
plt.xlabel('Types of the gill-size of the Mushrooms', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title('Distribution of the Mushrooms by their Classes and Gill-Size', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Distribution of the Mushrooms by their Classes and Gill-Size')

# %% [markdown]
# # Gill-Color

# %%
plt.figure(figsize=(15, 8))
splot = sns.countplot(data=df, x='gill-color', hue='class', order=df['gill-color'].value_counts().index, palette=['red', 'forestgreen'], edgecolor=(0, 0, 0),linewidth=2)
                      
splot.set_xticklabels(['Black', 'Brown', 'Buff', 'Chocolate', 'Gray', 'Green', 'Orange', 'Pink', 'Purple', 'Red', 'White', 'Yellow'])

for p in splot.patches:
    splot.annotate(format(p.get_height(), '.1f'),
                   (p.get_x() + p.get_width() / 2., p.get_height()),
                   ha='center', va='center',
                   xytext=(0, 9),
                   textcoords='offset points')
                   
plt.legend(['Poisonous', 'Edible'], loc='upper right')
plt.ylabel('Number of the Mushrooms', fontsize=14)
plt.xlabel('Types of the gill-color of the Mushrooms', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title('Distribution of the Mushrooms by their Classes and Gill-Color', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Distribution of the Mushrooms by their Classes and Gill-Color')

# %% [markdown]
# # Stalk-Shape

# %%
plt.figure(figsize=(15, 8))
splot = sns.countplot(data=df, x='stalk-shape', hue='class', order=df['stalk-shape'].value_counts().index, palette=['red', 'forestgreen'], edgecolor=(0, 0, 0),linewidth=2)
                      
splot.set_xticklabels(['Enlarging', 'Tapering'])

for p in splot.patches:
    splot.annotate(format(p.get_height(), '.1f'),
                   (p.get_x() + p.get_width() / 2., p.get_height()),
                   ha='center', va='center',
                   xytext=(0, 9),
                   textcoords='offset points')
                   
plt.legend(['Poisonous', 'Edible'], loc='upper right')
plt.ylabel('Number of the Mushrooms', fontsize=14)
plt.xlabel('Types of the stalk-shape of the Mushrooms', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title('Distribution of the Mushrooms by their Classes and Stalk-Shape', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Distribution of the Mushrooms by their Classes and Stalk-Shape')

# %% [markdown]
# # Stalk-Root

# %%
# The stalk-root feature has missing values. I filled the missing values with the most frequent object which is 'b'.
df = df.replace(['?'], 'b')

plt.figure(figsize=(15, 8))
splot = sns.countplot(data=df, x='stalk-root', hue='class', order=df['stalk-root'].value_counts().index, palette=['red', 'forestgreen'], edgecolor=(0, 0, 0), linewidth=2)

splot.set_xticklabels(['Bulbous', 'Equal', 'Club', 'Rooted'])

for p in splot.patches:
    splot.annotate(format(p.get_height(), '.1f'),
                   (p.get_x() + p.get_width() / 2., p.get_height()),
                   ha='center', va='center',
                   xytext=(0, 9),
                   textcoords='offset points')
plt.legend(['Poisonous', 'Edible'], loc='upper right')
plt.ylabel('Number of the Mushrooms', fontsize=14)
plt.xlabel('Types of the Stalk Roots', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title('Distribution of the Mushrooms by their Classes vs Stalk Root', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Distribution of the Mushrooms by their Classes vs Stalk Root')

# %% [markdown]
# # Stalk Surface Above Ring

# %%
plt.figure(figsize=(15, 8))
splot = sns.countplot(data=df, x='stalk-surface-above-ring', hue='class', order=df['stalk-surface-above-ring'].value_counts().index, palette=['red', 'forestgreen'], edgecolor=(0, 0, 0),linewidth=2)
                      
splot.set_xticklabels(['Fibrous', 'Scaly', 'Silky', 'Smooth'])

for p in splot.patches:
    splot.annotate(format(p.get_height(), '.1f'),
                   (p.get_x() + p.get_width() / 2., p.get_height()),
                   ha='center', va='center',
                   xytext=(0, 9),
                   textcoords='offset points')
                   
plt.legend(['Poisonous', 'Edible'], loc='upper right')
plt.ylabel('Number of the Mushrooms', fontsize=14)
plt.xlabel('Types of the stalk-surface-above-ring of the Mushrooms', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title('Distribution of the Mushrooms by their Classes and Stalk Surface Above Rings', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Distribution of the Mushrooms by their Classes and Stalk Surface Above Rings')

# %% [markdown]
# # Stalk Surface Below Ring

# %%
plt.figure(figsize=(15, 8))
splot = sns.countplot(data=df, x='stalk-surface-below-ring', hue='class', order=df['stalk-surface-below-ring'].value_counts().index, palette=['red', 'forestgreen'], edgecolor=(0, 0, 0),linewidth=2)
                      
splot.set_xticklabels(['Fibrous', 'Scaly', 'Silky', 'Smooth'])

for p in splot.patches:
    splot.annotate(format(p.get_height(), '.1f'),
                   (p.get_x() + p.get_width() / 2., p.get_height()),
                   ha='center', va='center',
                   xytext=(0, 9),
                   textcoords='offset points')
                   
plt.legend(['Poisonous', 'Edible'], loc='upper right')
plt.ylabel('Number of the Mushrooms', fontsize=14)
plt.xlabel('Types of the stalk-surface-below-ring of the Mushrooms', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title('Distribution of the Mushrooms by their Classes and Stalk Surface Below Rings', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Distribution of the Mushrooms by their Classes and Stalk Surface Below Rings')

# %% [markdown]
# # Stalk Color Above Ring

# %%
plt.figure(figsize=(15, 8))
splot = sns.countplot(data=df, x='stalk-color-above-ring', hue='class', order=df['stalk-color-above-ring'].value_counts().index, palette=['red', 'forestgreen'], edgecolor=(0, 0, 0),linewidth=2)
                      
splot.set_xticklabels(['Brown', 'Buff', 'Cinnamon', 'Gray', 'Orange', 'Pink', 'Red', 'White', 'Yellow'])

for p in splot.patches:
    splot.annotate(format(p.get_height(), '.1f'),
                   (p.get_x() + p.get_width() / 2., p.get_height()),
                   ha='center', va='center',
                   xytext=(0, 9),
                   textcoords='offset points')
                   
plt.legend(['Poisonous', 'Edible'], loc='upper right')
plt.ylabel('Number of the Mushrooms', fontsize=14)
plt.xlabel('Types of the stalk-color-above-ring of the Mushrooms', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title('Distribution of the Mushrooms by their Classes and Stalk Color Above Ring', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Distribution of the Mushrooms by their Classes and Stalk Color Above Ring')

# %% [markdown]
# # Stalk Color Below Ring

# %%
plt.figure(figsize=(15, 8))
splot = sns.countplot(data=df, x='stalk-color-below-ring', hue='class', order=df['stalk-color-below-ring'].value_counts().index, palette=['red', 'forestgreen'], edgecolor=(0, 0, 0),linewidth=2)
                      
splot.set_xticklabels(['Brown', 'Buff', 'Cinnamon', 'Gray', 'Orange', 'Pink', 'Red', 'White', 'Yellow'])

for p in splot.patches:
    splot.annotate(format(p.get_height(), '.1f'),
                   (p.get_x() + p.get_width() / 2., p.get_height()),
                   ha='center', va='center',
                   xytext=(0, 9),
                   textcoords='offset points')
                   
plt.legend(['Poisonous', 'Edible'], loc='upper right')
plt.ylabel('Number of the Mushrooms', fontsize=14)
plt.xlabel('Types of the stalk-color-below-ring of the Mushrooms', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title('Distribution of the Mushrooms by their Classes and Stalk Color Below Ring', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Distribution of the Mushrooms by their Classes and Stalk Color Below Ring')

# %% [markdown]
# # Veil Types

# %%
plt.figure(figsize=(15, 8))
splot = sns.countplot(data=df, x='veil-type', hue='class', order=df['veil-type'].value_counts().index, palette=['red', 'forestgreen'], edgecolor=(0, 0, 0),linewidth=2)
                      
splot.set_xticklabels(['Partial'])

for p in splot.patches:
    splot.annotate(format(p.get_height(), '.1f'),
                   (p.get_x() + p.get_width() / 2., p.get_height()),
                   ha='center', va='center',
                   xytext=(0, 9),
                   textcoords='offset points')
                   
plt.legend(['Poisonous', 'Edible'], loc='upper right')
plt.ylabel('Number of the Mushrooms', fontsize=14)
plt.xlabel('Types of the veil-type of the Mushrooms', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title('Distribution of the Mushrooms by their Classes and Veil Types', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Distribution of the Mushrooms by their Classes and Veil Types')

# %% [markdown]
# # Veil Color

# %%
plt.figure(figsize=(15, 8))
splot = sns.countplot(data=df, x='veil-color', hue='class', order=df['veil-color'].value_counts().index, palette=['red', 'forestgreen'], edgecolor=(0, 0, 0),linewidth=2)
                      
splot.set_xticklabels(['Brrown', 'Orange', 'White', 'Yellow'])

for p in splot.patches:
    splot.annotate(format(p.get_height(), '.1f'),
                   (p.get_x() + p.get_width() / 2., p.get_height()),
                   ha='center', va='center',
                   xytext=(0, 9),
                   textcoords='offset points')
                   
plt.legend(['Poisonous', 'Edible'], loc='upper right')
plt.ylabel('Number of the Mushrooms', fontsize=14)
plt.xlabel('Types of the veil-color of the Mushrooms', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title('Distribution of the Mushrooms by their Classes and Veil-Color', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Distribution of the Mushrooms by their Classes and Veil-Color')

# %% [markdown]
# # Ring Numbers

# %%
plt.figure(figsize=(15, 8))
splot = sns.countplot(data=df, x='ring-number', hue='class', order=df['ring-number'].value_counts().index, palette=['red', 'forestgreen'], edgecolor=(0, 0, 0),linewidth=2)
                      
splot.set_xticklabels(['None', 'One', 'Two'])

for p in splot.patches:
    splot.annotate(format(p.get_height(), '.1f'),
                   (p.get_x() + p.get_width() / 2., p.get_height()),
                   ha='center', va='center',
                   xytext=(0, 9),
                   textcoords='offset points')
                   
plt.legend(['Poisonous', 'Edible'], loc='upper right')
plt.ylabel('Number of the Mushrooms', fontsize=14)
plt.xlabel('Types of the ring-number of the Mushrooms', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title('Distribution of the Mushrooms by their Classes and Ring-Number', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Distribution of the Mushrooms by their Classes and Ring-Number')

# %% [markdown]
# # Ring Types

# %%
plt.figure(figsize=(15, 8))
splot = sns.countplot(data=df, x='ring-type', hue='class', order=df['ring-type'].value_counts().index, palette=['red', 'forestgreen'], edgecolor=(0, 0, 0),linewidth=2)
                      
splot.set_xticklabels(['Evanescent', 'Flaring', 'Large', 'None', 'Pendant'])

for p in splot.patches:
    splot.annotate(format(p.get_height(), '.1f'),
                   (p.get_x() + p.get_width() / 2., p.get_height()),
                   ha='center', va='center',
                   xytext=(0, 9),
                   textcoords='offset points')
                   
plt.legend(['Poisonous', 'Edible'], loc='upper right')
plt.ylabel('Number of the Mushrooms', fontsize=14)
plt.xlabel('Types of the rinng-type of the Mushrooms', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title('Distribution of the Mushrooms by their Classes and Ring Types', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Distribution of the Mushrooms by their Classes and Ring Types')

# %% [markdown]
# # Spore Print Colors

# %%
plt.figure(figsize=(15, 8))
splot = sns.countplot(data=df, x='spore-print-color', hue='class', order=df['spore-print-color'].value_counts().index, palette=['red', 'forestgreen'], edgecolor=(0, 0, 0),linewidth=2)
                      
splot.set_xticklabels(['Black', 'Brown', 'Buff', 'Chocolate', 'Green', 'Orange', 'Purple', 'White', 'Yellow'])

for p in splot.patches:
    splot.annotate(format(p.get_height(), '.1f'),
                   (p.get_x() + p.get_width() / 2., p.get_height()),
                   ha='center', va='center',
                   xytext=(0, 9),
                   textcoords='offset points')
                   
plt.legend(['Poisonous', 'Edible'], loc='upper right')
plt.ylabel('Number of the Mushrooms', fontsize=14)
plt.xlabel('Types of the spore-print-color of the Mushrooms', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title('Distribution of the Mushrooms by their Classes and Spore Print Colors', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Distribution of the Mushrooms by their Classes and Spore Print Colors')

# %% [markdown]
# # Population

# %%
plt.figure(figsize=(15, 8))
splot = sns.countplot(data=df, x='population', hue='class', order=df['population'].value_counts().index, palette=['red', 'forestgreen'], edgecolor=(0, 0, 0),linewidth=2)
                      
splot.set_xticklabels(['Abundant', 'Clustered', 'Numerous', 'Scattered', 'Several', 'Solitary'])

for p in splot.patches:
    splot.annotate(format(p.get_height(), '.1f'),
                   (p.get_x() + p.get_width() / 2., p.get_height()),
                   ha='center', va='center',
                   xytext=(0, 9),
                   textcoords='offset points')
                   
plt.legend(['Poisonous', 'Edible'], loc='upper right')
plt.ylabel('Number of the Mushrooms', fontsize=14)
plt.xlabel('Types of the Population of the Mushrooms', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title('Distribution of the Mushrooms by their Classes and Population', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Distribution of the Mushrooms by their Classes and Population')

# %% [markdown]
# # Habitats

# %%
plt.figure(figsize=(15, 8))
splot = sns.countplot(data=df, x='habitat', hue='class', order=df['habitat'].value_counts().index, palette=['red', 'forestgreen'], edgecolor=(0, 0, 0),linewidth=2)
                      
splot.set_xticklabels(['Grasses', 'Leaves', 'Meadows', 'Paths', 'Urban', 'Waste', 'Woods'])

for p in splot.patches:
    splot.annotate(format(p.get_height(), '.1f'),
                   (p.get_x() + p.get_width() / 2., p.get_height()),
                   ha='center', va='center',
                   xytext=(0, 9),
                   textcoords='offset points')
                   
plt.legend(['Poisonous', 'Edible'], loc='upper right')
plt.ylabel('Number of the Mushrooms', fontsize=14)
plt.xlabel('Types of the habitat of the Mushrooms', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title('Distribution of the Mushrooms by their Classes and Habitats', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Distribution of the Mushrooms by their Classes and Habitats')

# %%
len(df.columns)
# Out:
# 23

# %%
df.dtypes
# Out:
# class                       object
# cap-shape                   object
# cap-surface                 object
# cap-color                   object
# bruises                     object
# odor                        object
# gill-attachment             object
# gill-spacing                object
# gill-size                   object
# gill-color                  object
# stalk-shape                 object
# stalk-root                  object
# stalk-surface-above-ring    object
# stalk-surface-below-ring    object
# stalk-color-above-ring      object
# stalk-color-below-ring      object
# veil-type                   object
# veil-color                  object
# ring-number                 object
# ring-type                   object
# spore-print-color           object
# population                  object
# habitat                     object
# dtype: object

# %%
df['class'] = df['class'].astype('category')

# %%
df.dtypes
# Out:
# class                       category
# cap-shape                     object
# cap-surface                   object
# cap-color                     object
# bruises                       object
# odor                          object
# gill-attachment               object
# gill-spacing                  object
# gill-size                     object
# gill-color                    object
# stalk-shape                   object
# stalk-root                    object
# stalk-surface-above-ring      object
# stalk-surface-below-ring      object
# stalk-color-above-ring        object
# stalk-color-below-ring        object
# veil-type                     object
# veil-color                    object
# ring-number                   object
# ring-type                     object
# spore-print-color             object
# population                    object
# habitat                       object
# dtype: object

# %%
df['class'].cat.codes
# Out:
# 0       1
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 8119    0
# 8120    0
# 8121    0
# 8122    1
# 8123    0
# Length: 8124, dtype: int8

# %%
df
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %%
df['class'].value_counts() # display number of samples on each class
# Out:
# e    4208
# p    3916
# Name: class, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()
for column in df.columns:
    df[column] = labelencoder.fit_transform(df[column])

# %%
df.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      1          5            2          4        1     6                1
# 1      0          5            2          9        1     0                1
# 2      0          0            2          8        1     3                1
# 3      1          5            3          8        1     6                1
# 4      0          5            2          3        0     5                1
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-below-ring  \
# 0             0          1           4  ...                         2
# 1             0          0           4  ...                         2
# 2             0          0           5  ...                         2
# 3             0          1           5  ...                         2
# 4             1          0           4  ...                         2
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# ...

# %%
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')
# "class" column as numpy array.
y = df["class"].values

# All data except "class" column.
x = df.drop(["class"], axis=1).values

# Split data for train and test.
x_train, x_test, y_train, y_test = train_test_split(x,y,random_state=42,test_size=0.2)
x_train, y_train
x_test, y_test
# Out:
# (array([[2, 0, 4, ..., 3, 3, 1],
#         [2, 2, 2, ..., 7, 4, 2],
#         [5, 3, 4, ..., 7, 4, 2],
#         ...,
#         [5, 3, 4, ..., 7, 4, 4],
#         [3, 3, 4, ..., 7, 4, 4],
#         [5, 0, 9, ..., 1, 5, 4]]),
#  array([0, 1, 1, ..., 1, 1, 1]))

# %% [markdown]
# # Classification using Logistic Regression Technique

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
print("Test Accuracy: {}%".format(round(lr.score(x_test,y_test)*100,2)))
# Out:
# Test Accuracy: 95.38%

# %%
print("Test Accuracy: {}%".format(round(lr.score(x_train,y_train)*100,2)))
# Out:
# Test Accuracy: 95.85%

# %% [markdown]
# # Classification using Support Vector Machine Technique

# %%
from sklearn.svm import SVC

SVM = SVC(random_state=42, gamma="auto")
SVM.fit(x_train, y_train)
# Out:
# SVC(gamma='auto', random_state=42)

# %%
print("Test Accuracy: {}%".format(round(SVM.score(x_test,y_test)*100,2)))
# Out:
# Test Accuracy: 100.0%

# %%
print("Test Accuracy: {}%".format(round(SVM.score(x_train,y_train)*100,2)))
# Out:
# Test Accuracy: 100.0%

# %% [markdown]
# # Classification using K- Nearest Neighbors Technique

# %%
from sklearn.neighbors import KNeighborsClassifier as KNC

bestK_value = 0
bestK_score = 0

for i in range(1,10):
    knn = KNC(n_neighbors=i)
    knn.fit(x_train, y_train)
    if knn.score(x_test, y_test)>bestK_score:
        bestK_score = knn.score(x_train, y_train)
        bestK_value = i

# %%
print("""Best KNN Value: {}
Test Accuracy: {}%""".format(bestK_value,round(knn.score(x_test,y_test)*100,2)))
# Out:
# Best KNN Value: 1
# Test Accuracy: 99.57%

# %% [markdown]
# # Classification using Naive Bayes Technique

# %%
from sklearn.naive_bayes import GaussianNB

NB = GaussianNB()
NB.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
print("Test accuracy: {}%".format(round(NB.score(x_test, y_test)*100,2)))
# Out:
# Test accuracy: 90.28%

# %% [markdown]
# # Classification using Decision Tree Technique

# %%
from sklearn.tree import DecisionTreeClassifier

DTC = DecisionTreeClassifier()
DTC.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
print("Test Accuracy: {}%".format(round(DTC.score(x_test, y_test)*100,2)))
# Out:
# Test Accuracy: 100.0%

# %%
from sklearn.tree import plot_tree
from sklearn import tree

tree.plot_tree(DTC);

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor()
rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
print("Test Accuracy: {}%".format(round(rf.score(x_test, y_test)*100,2)))
# Out:
# Test Accuracy: 100.0%

# %% [markdown]
# # Building Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

# %%
# Linear Regression

y_pred_lr = lr.predict(x_test)
y_true_lr = y_test
cm = confusion_matrix(y_true_lr, y_pred_lr)
f, ax = plt.subplots(figsize = (5,5))
sns.heatmap(cm, annot=True, linewidths=0.5, linecolor="red", fmt = ".0f", ax = ax)
plt.xlabel("y_pred_lr")
plt.ylabel("y_true_lr")
plt.show()

# %%
# SVM

y_pred_SVM = SVM.predict(x_test)
y_true_SVM = y_test
cm = confusion_matrix(y_pred_SVM, y_true_SVM)
f, ax = plt.subplots(figsize = (5,5))
sns.heatmap(cm, annot=True, linewidths=0.5, linecolor="red", fmt = ".0f", ax = ax)
plt.xlabel("y_pred_SVM")
plt.ylabel("y_true_SVM")
plt.show()

# %%
# KNN

y_pred_knn = knn.predict(x_test)
y_true_knn = y_test
cm = confusion_matrix(y_pred_knn, y_true_knn)
f, ax = plt.subplots(figsize = (5,5))
sns.heatmap(cm, annot=True, linewidths=0.5, linecolor="red", fmt = ".0f", ax = ax)
plt.xlabel("y_pred_knn")
plt.ylabel("y_true_knn")
plt.show()

# %%
# Naive Bayes

y_pred_NB = NB.predict(x_test)
y_true_NB = y_test
cm = confusion_matrix(y_pred_NB, y_true_NB)
f, ax = plt.subplots(figsize = (5,5))
sns.heatmap(cm, annot=True, linewidths=0.5, linecolor="red", fmt = ".0f", ax = ax)
plt.xlabel("y_pred_NB")
plt.ylabel("y_true_NB")
plt.show()

# %%
# Decision Tree

y_pred_DTC = DTC.predict(x_test)
y_true_DTC = y_test
cm = confusion_matrix(y_pred_DTC, y_true_DTC)
f, ax = plt.subplots(figsize = (6,6))
sns.heatmap(cm, annot=True, linewidths=0.5, linecolor="red", fmt = ".0f", ax = ax)
plt.xlabel("y_pred_DTC")
plt.ylabel("y_true_DTC")
plt.show()

# %%
# Encoding the string-type data points

df2 = pd.get_dummies(df)

y = df2[['class']]   # The label for the machine learning models
X = df2.drop(['class'], axis=1)   #Features

X
# Out:
#       cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0             5            2          4        1     6                1
# 1             5            2          9        1     0                1
# 2             0            2          8        1     3                1
# 3             5            3          8        1     6                1
# 4             5            2          3        0     5                1
# ...         ...          ...        ...      ...   ...              ...
# 8119          3            2          4        0     5                0
# 8120          5            2          4        0     5                0
# 8121          2            2          4        0     5                0
# 8122          3            3          4        0     8                1
# 8123          5            2          4        0     5                0
#
#       gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# ...

# %%
trainX, testX, trainY, testY = train_test_split(X, y, test_size=0.2, shuffle=True, random_state=13)
trainX.head()
# Out:
#       cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 8109          0            2          8        0     5                1
# 6711          5            2          4        0     2                1
# 7991          3            2          3        0     5                1
# 6987          5            3          2        0     2                1
# 7120          5            2          4        0     7                1
#
#       gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# 8109             1          0          10            0  ...
# 6711             0          1           0            1  ...
# 7991             1          0          10            0  ...
# 6987             0          1           0            1  ...
# 7120             0          1           0            1  ...
#
#       stalk-surface-below-ring  stalk-color-above-ring  \
# 8109                         2                       7
# 6711                         1                       7
# ...

# %%
# trainY set which is labels
trainY.head()
# Out:
#       class
# 8109      0
# 6711      1
# 7991      0
# 6987      1
# 7120      1

# %% [markdown]
# # Random Forest Classifier
# # In this step, I will train a Random Forest Classifier model and check the results.

# %%
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
rf = RandomForestClassifier(oob_score=True)
rf.fit(trainX, trainY)

train_scoreRF = rf.score(trainX, trainY)
oob_score = rf.oob_score_
Adjusted_R2_trainRF = 1 - (1 - rf.score(trainX, trainY)) * (len(trainY) - 1) / (len(trainY) - trainX.shape[1] - 1)
Adjusted_R2_testRF = 1 - (1 - rf.score(testX, testY)) * (len(testY) - 1) / (len(testY) - testX.shape[1] - 1)

print('Train Adjusted R2: %', Adjusted_R2_trainRF * 100)
print('Test Adjusted R2: %', Adjusted_R2_testRF * 100)
print('OOB Score: %', oob_score * 100)
# Out:
# Train Adjusted R2: % 100.0
# Test Adjusted R2: % 100.0
# OOB Score: % 100.0

# %%
predictions_rf = pd.DataFrame(rf.predict(testX))
plt.figure(figsize=(12, 8))
conf_mat = confusion_matrix(y_true=testY['class'], y_pred=predictions_rf[0])
sns.heatmap(conf_mat, annot=True, fmt='g')
plt.title('Confusion Matrix of the Test Data (Edible Class Based)', fontsize=14)
plt.ylabel('Real Class', fontsize=12)
plt.xlabel('Predicted Class', fontsize=12)
plt.show()

# %% [markdown]
# # XGB Classifier

# %%
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
model = XGBClassifier(learning_rate=0.005, max_depth=10, n_estimators=30, colsample_bytree=0.3, min_child_weight=0.5, reg_alpha=0.3,)
model.fit(trainX, trainY['class'])

predictions_XGBC = model.predict(testX)
acc_XGBC = accuracy_score(predictions_XGBC, testY['class'])
print('----------------------------------------------------')
print('Accuracy of XGBClassifier: %', 100 * acc_XGBC)
# Out:
# ----------------------------------------------------
# Accuracy of XGBClassifier: % 100.0
